# %%
import json
import pandas as pd
import seaborn as sns

# %%
all_tweets = pd.read_json("data/baby_formula.json")

# %%
all_tweets_sample = all_tweets.sample(500)
all_tweets_sample
# Out:
#                          id  \
# 335017  1525139072884219904
# 313439  1525206832209399808
# 546939  1519755456666812416
# 410715  1524806516167122944
# 543679  1520912983051980800
# ...                     ...
# 478401  1524360230892707840
# 414985  1524794481308057600
# 102887  1527234504259141632
# 288676  1525294672104390656
# 293591  1525275404197670912
#
#                                                      text  \
# 335017  @Jim_Jordan While Americans needs Baby Formula...
# 313439  @durbinwatson09 @Stockanalysis11 @TomiLahren L...
# 546939  Due to #TigraySiege, lactating women are unabl...
# 410715  @RepMTG Where are you getting this info that “...
# 543679                            https://t.co/qBLl0nFFgv
# ...                                                   ...
# 478401  Nationwide about 40% of large retail stores ar...
# 414985  Don't you mean withholds Baby formula. https:/...
# 102887  @seanhannity Only 12 House Republicans voted F...
# 288676  @SenSchumer Most Americans will remember the p...
# 293591  I could only breastfeed for about 8 weeks. I g...
#
#                   author_id                created_at  \
# 335017   903439126736732160 2022-05-13 15:41:05+00:00
# 313439  1474200923979321344 2022-05-13 20:10:20+00:00
# 546939  1457000608423100416 2022-04-28 19:08:31+00:00
# 410715           1918429483 2022-05-12 17:39:37+00:00
# 543679           1727008657 2022-05-01 23:48:07+00:00
# ...                     ...                       ...
# 478401   761024878396878848 2022-05-11 12:06:14+00:00
# 414985  1456283604359725056 2022-05-12 16:51:48+00:00
# 102887             24568381 2022-05-19 10:27:35+00:00
# 288676  1112659779380346880 2022-05-14 01:59:23+00:00
# 293591  1283142935257677824 2022-05-14 00:42:49+00:00
#
#                                            public_metrics  \
# 335017  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 313439  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 546939  {'retweet_count': 55, 'reply_count': 0, 'like_...
# 410715  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 543679  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...                                                   ...
# 478401  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 414985  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 102887  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 288676  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 293591  {'retweet_count': 1, 'reply_count': 1, 'like_c...
#
#                                                  entities  \
# 335017  {'mentions': [{'start': 0, 'end': 11, 'usernam...
# 313439  {'urls': [{'start': 165, 'end': 188, 'url': 'h...
# 546939  {'hashtags': [{'start': 7, 'end': 19, 'tag': '...
# 410715  {'mentions': [{'start': 0, 'end': 7, 'username...
# 543679  {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# ...                                                   ...
# 478401  {'urls': [{'start': 88, 'end': 111, 'url': 'ht...
# 414985  {'urls': [{'start': 39, 'end': 62, 'url': 'htt...
# 102887  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 288676  {'mentions': [{'start': 0, 'end': 11, 'usernam...
# 293591                                                NaN
#
#                                                    author withheld
# 335017  {'username': 'PrerunnerPilot', 'verified': Fal...      NaN
# 313439  {'username': 'MarketJunkie73', 'name': 'Garric...      NaN
# 546939  {'username': 'Genibelay3', 'public_metrics': {...      NaN
# 410715  {'verified': False, 'name': 'Eric', 'public_me...      NaN
# 543679  {'name': '#primalscreamgrammy', 'id': '1727008...      NaN
# ...                                                   ...      ...
# 478401  {'username': 'Nor_Kan_1965', 'name': 'Mark Dor...      NaN
# 414985  {'username': 'briangoth151', 'verified': False...      NaN
# 102887  {'username': 'FLSwampBoy', 'verified': False, ...      NaN
# 288676  {'id': '1112659779380346880', 'username': 'kob...      NaN
# 293591  {'verified': False, 'name': 'Famous Amos 🍪', '...      NaN
#
# [500 rows x 8 columns]

# %% [markdown]
# ### Cleaning Text

# %%
import re

import nltk.corpus
nltk.download('stopwords')
from nltk.corpus import stopwords

import nltk
nltk.download('omw-1.4')
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

def clean_text_basic(text):
    '''
    Normalizes text, removes unicode chars
        Params:
            text (string): text to be normalized
        Returns:
            cleaned_text (string): The text cleaned with the steps above
    '''
    # regular expression from https://monkeylearn.com/blog/text-cleaning/
    cleaned_text = re.sub(r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", text)
    cleaned_text = cleaned_text.lower()
    return cleaned_text

def clean_text_level2(text):
    '''
    Cleans with the basic steps but also removes stop words and lemmatizes
        Params:
            text (string): text to be normalized
        Returns:
            cleaned_text (string): The text cleaned with the steps above
    '''
    text = clean_text_basic(text)
    stoppies = stopwords.words('english')
    lemmatizer = WordNetLemmatizer()
    # expression partially from https://monkeylearn.com/blog/text-cleaning/
    cleaned_text = " ".join([lemmatizer.lemmatize(word) for word in text.split() if word not in (stoppies)])
    return cleaned_text
# Out:
# [nltk_data] Downloading package stopwords to /home/rohan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/rohan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
all_tweets_sample["clean_text"] = all_tweets_sample["text"].apply(clean_text_basic)
all_tweets_sample["very_clean_text"] = all_tweets_sample["text"].apply(clean_text_level2)
all_tweets_sample
# Out:
#                          id  \
# 335017  1525139072884219904
# 313439  1525206832209399808
# 546939  1519755456666812416
# 410715  1524806516167122944
# 543679  1520912983051980800
# ...                     ...
# 478401  1524360230892707840
# 414985  1524794481308057600
# 102887  1527234504259141632
# 288676  1525294672104390656
# 293591  1525275404197670912
#
#                                                      text  \
# 335017  @Jim_Jordan While Americans needs Baby Formula...
# 313439  @durbinwatson09 @Stockanalysis11 @TomiLahren L...
# 546939  Due to #TigraySiege, lactating women are unabl...
# 410715  @RepMTG Where are you getting this info that “...
# 543679                            https://t.co/qBLl0nFFgv
# ...                                                   ...
# 478401  Nationwide about 40% of large retail stores ar...
# 414985  Don't you mean withholds Baby formula. https:/...
# 102887  @seanhannity Only 12 House Republicans voted F...
# 288676  @SenSchumer Most Americans will remember the p...
# 293591  I could only breastfeed for about 8 weeks. I g...
#
#                   author_id                created_at  \
# 335017   903439126736732160 2022-05-13 15:41:05+00:00
# 313439  1474200923979321344 2022-05-13 20:10:20+00:00
# 546939  1457000608423100416 2022-04-28 19:08:31+00:00
# 410715           1918429483 2022-05-12 17:39:37+00:00
# 543679           1727008657 2022-05-01 23:48:07+00:00
# ...                     ...                       ...
# 478401   761024878396878848 2022-05-11 12:06:14+00:00
# 414985  1456283604359725056 2022-05-12 16:51:48+00:00
# 102887             24568381 2022-05-19 10:27:35+00:00
# 288676  1112659779380346880 2022-05-14 01:59:23+00:00
# 293591  1283142935257677824 2022-05-14 00:42:49+00:00
#
#                                            public_metrics  \
# 335017  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 313439  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 546939  {'retweet_count': 55, 'reply_count': 0, 'like_...
# 410715  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 543679  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...                                                   ...
# 478401  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 414985  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 102887  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 288676  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 293591  {'retweet_count': 1, 'reply_count': 1, 'like_c...
#
#                                                  entities  \
# 335017  {'mentions': [{'start': 0, 'end': 11, 'usernam...
# 313439  {'urls': [{'start': 165, 'end': 188, 'url': 'h...
# 546939  {'hashtags': [{'start': 7, 'end': 19, 'tag': '...
# 410715  {'mentions': [{'start': 0, 'end': 7, 'username...
# 543679  {'urls': [{'start': 0, 'end': 23, 'url': 'http...
# ...                                                   ...
# 478401  {'urls': [{'start': 88, 'end': 111, 'url': 'ht...
# 414985  {'urls': [{'start': 39, 'end': 62, 'url': 'htt...
# 102887  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 288676  {'mentions': [{'start': 0, 'end': 11, 'usernam...
# 293591                                                NaN
#
#                                                    author withheld  \
# 335017  {'username': 'PrerunnerPilot', 'verified': Fal...      NaN
# 313439  {'username': 'MarketJunkie73', 'name': 'Garric...      NaN
# 546939  {'username': 'Genibelay3', 'public_metrics': {...      NaN
# 410715  {'verified': False, 'name': 'Eric', 'public_me...      NaN
# 543679  {'name': '#primalscreamgrammy', 'id': '1727008...      NaN
# ...                                                   ...      ...
# 478401  {'username': 'Nor_Kan_1965', 'name': 'Mark Dor...      NaN
# 414985  {'username': 'briangoth151', 'verified': False...      NaN
# 102887  {'username': 'FLSwampBoy', 'verified': False, ...      NaN
# 288676  {'id': '1112659779380346880', 'username': 'kob...      NaN
# 293591  {'verified': False, 'name': 'Famous Amos 🍪', '...      NaN
#
#                                                clean_text  \
# 335017  jimjordan while americans needs baby formula b...
# 313439  durbinwatson09 stockanalysis11 tomilahren lol ...
# 546939  due to tigraysiege lactating women are unable ...
# 410715  repmtg where are you getting this info that pa...
# 543679
# ...                                                   ...
# 478401  nationwide about 40 of large retail stores are...
# 414985              dont you mean withholds baby formula
# 102887  seanhannity only 12 house republicans voted fo...
# 288676  senschumer most americans will remember the pr...
# 293591  i could only breastfeed for about 8 weeks i go...
#
#                                           very_clean_text
# 335017  jimjordan american need baby formula biden amp...
# 313439  durbinwatson09 stockanalysis11 tomilahren lol ...
# 546939  due tigraysiege lactating woman unable breastf...
# 410715  repmtg getting info pallet baby formula going ...
# 543679
# ...                                                   ...
# 478401  nationwide 40 large retail store stock 31 mida...
# 414985                   dont mean withholds baby formula
# 102887  seanhannity 12 house republican voted bill wou...
# 288676  senschumer american remember price gas food la...
# 293591  could breastfeed 8 week got mastitis twice hel...
#
# [500 rows x 10 columns]

# %% [markdown]
# ### Sentiment Analyzers

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
import operator
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
def get_sentiment(text):
    '''
    Gets the sentiment score of text from the nltk sentiment thingy.
        Params:
            text (string): Text to analyze
        Returns:
            sent (float): Real number from -1 to 1
    '''
    return sia.polarity_scores(text)["compound"]
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/rohan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
all_tweets_sample["sentiment"] = all_tweets_sample["clean_text"].apply(get_sentiment)
all_tweets_sample["very_clean_sentiment"] = all_tweets_sample["very_clean_text"].apply(get_sentiment)

# %%
def show_sentiments(index):
    display(all_tweets_sample["text"].iloc[index])
    display(all_tweets_sample["sentiment"].iloc[index])
    display(all_tweets_sample["very_clean_sentiment"].iloc[index])
show_sentiments(3)
# Out:
# '@RepMTG Where are you getting this info that “pallets of baby formula” are going to the border?!????  You fucking lying pig cunt!'
# -0.7996
# -0.7996

# %%
sns.displot(all_tweets_sample["sentiment"], kde=True)

# %%
sns.displot(all_tweets_sample["very_clean_sentiment"], kde=True)
