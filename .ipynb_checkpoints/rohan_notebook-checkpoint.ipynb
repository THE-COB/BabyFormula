# %%
import json
import pandas as pd
import seaborn as sns

# %%
all_tweets = pd.read_json("data/baby_formula.json")

# %%
all_tweets_sample = all_tweets.sample(1000)
all_tweets_sample
# Out:
#                          id  \
# 427640  1524755141542703104
# 174922  1526459709590589440
# 82654   1527313295421542400
# 80161   1527321095581229056
# 473759  1524392800288051200
# ...                     ...
# 44653   1527467955814006784
# 385544  1524879439057760256
# 372971  1524919846336593920
# 405578  1524823196796604416
# 303882  1525238914742636544
#
#                                                      text  \
# 427640  @DMoehnert @OldSalz @MailOnline There was a da...
# 174922  "Karine Jean-Pierre can't point to a single me...
# 82654         @elonmusk Are you against baby formula too?
# 80161   @RobertKennedyJr @rosadelauro To order baby fo...
# 473759            @reallygraceful https://t.co/OTV6KPGIJO
# ...                                                   ...
# 44653   @SenatorTimScott Tim… the dems are onto aborti...
# 385544  The Biden Administration Is Shipping Pallets o...
# 372971  @haxanvillain @somehuskervbguy @toddstarnes Bu...
# 405578              @JackPosobiec https://t.co/uNHE2wBpjn
# 303882  @IDzine01 I don't know. It feels like so many ...
#
#                   author_id                created_at  \
# 427640  1492616381715656704 2022-05-12 14:15:28+00:00
# 174922             21538153 2022-05-17 07:08:49+00:00
# 82654   1514353786457710592 2022-05-19 15:40:40+00:00
# 80161            3065078416 2022-05-19 16:11:40+00:00
# 473759           2722561800 2022-05-11 14:15:40+00:00
# ...                     ...                       ...
# 44653   1521322469738655744 2022-05-20 01:55:14+00:00
# 385544           2340448195 2022-05-12 22:29:23+00:00
# 372971  1300485332559855616 2022-05-13 01:09:57+00:00
# 405578  1347917501150224384 2022-05-12 18:45:54+00:00
# 303882             77299448 2022-05-13 22:17:49+00:00
#
#                                            public_metrics  \
# 427640  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 174922  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 82654   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 80161   {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 473759  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...                                                   ...
# 44653   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 385544  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 372971  {'retweet_count': 0, 'reply_count': 2, 'like_c...
# 405578  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 303882  {'retweet_count': 0, 'reply_count': 1, 'like_c...
#
#                                                  entities  \
# 427640  {'mentions': [{'start': 0, 'end': 10, 'usernam...
# 174922  {'urls': [{'start': 137, 'end': 160, 'url': 'h...
# 82654   {'mentions': [{'start': 0, 'end': 9, 'username...
# 80161   {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 473759  {'mentions': [{'start': 0, 'end': 15, 'usernam...
# ...                                                   ...
# 44653   {'annotations': [{'start': 17, 'end': 19, 'pro...
# 385544  {'urls': [{'start': 75, 'end': 98, 'url': 'htt...
# 372971  {'annotations': [{'start': 56, 'end': 58, 'pro...
# 405578  {'mentions': [{'start': 0, 'end': 13, 'usernam...
# 303882  {'mentions': [{'start': 0, 'end': 9, 'username...
#
#                                                    author withheld
# 427640  {'created_at': '2022-02-12T21:47:58.000Z', 'na...      NaN
# 174922  {'public_metrics': {'followers_count': 1379, '...      NaN
# 82654   {'public_metrics': {'followers_count': 14, 'fo...      NaN
# 80161   {'verified': False, 'name': 'Dave Swartout', '...      NaN
# 473759  {'username': 'JohnSmith872987', 'id': '2722561...      NaN
# ...                                                   ...      ...
# 44653   {'username': 'RaulFlo09225188', 'name': 'Racer...      NaN
# 385544  {'verified': False, 'name': 'Tom Souther', 'us...      NaN
# 372971  {'public_metrics': {'followers_count': 1426, '...      NaN
# 405578  {'id': '1347917501150224389', 'username': 'She...      NaN
# 303882  {'created_at': '2009-09-25T20:10:46.000Z', 'id...      NaN
#
# [1000 rows x 8 columns]

# %% [markdown]
# ### Cleaning Text

# %%
import re

import nltk.corpus
nltk.download('stopwords')
from nltk.corpus import stopwords

import nltk
nltk.download('omw-1.4')
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

def clean_text_basic(text):
    '''
    Normalizes text, removes unicode chars
        Params:
            text (string): text to be normalized
        Returns:
            cleaned_text (string): The text cleaned with the steps above
    '''
    # regular expression from https://monkeylearn.com/blog/text-cleaning/
    cleaned_text = re.sub(r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", text)
    cleaned_text = cleaned_text.lower()
    return cleaned_text

def clean_text_level2(text):
    '''
    Cleans with the basic steps but also removes stop words and lemmatizes
        Params:
            text (string): text to be normalized
        Returns:
            cleaned_text (string): The text cleaned with the steps above
    '''
    text = clean_text_basic(text)
    stoppies = stopwords.words('english')
    lemmatizer = WordNetLemmatizer()
    # expression partially from https://monkeylearn.com/blog/text-cleaning/
    cleaned_text = " ".join([lemmatizer.lemmatize(word) for word in text.split() if word not in (stoppies)])
    return cleaned_text
# Out:
# [nltk_data] Downloading package stopwords to /home/rohan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/rohan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
all_tweets_sample["clean_text"] = all_tweets_sample["text"].apply(clean_text_basic)
all_tweets_sample["very_clean_text"] = all_tweets_sample["text"].apply(clean_text_level2)
all_tweets_sample
# Out:
#                          id  \
# 427640  1524755141542703104
# 174922  1526459709590589440
# 82654   1527313295421542400
# 80161   1527321095581229056
# 473759  1524392800288051200
# ...                     ...
# 44653   1527467955814006784
# 385544  1524879439057760256
# 372971  1524919846336593920
# 405578  1524823196796604416
# 303882  1525238914742636544
#
#                                                      text  \
# 427640  @DMoehnert @OldSalz @MailOnline There was a da...
# 174922  "Karine Jean-Pierre can't point to a single me...
# 82654         @elonmusk Are you against baby formula too?
# 80161   @RobertKennedyJr @rosadelauro To order baby fo...
# 473759            @reallygraceful https://t.co/OTV6KPGIJO
# ...                                                   ...
# 44653   @SenatorTimScott Tim… the dems are onto aborti...
# 385544  The Biden Administration Is Shipping Pallets o...
# 372971  @haxanvillain @somehuskervbguy @toddstarnes Bu...
# 405578              @JackPosobiec https://t.co/uNHE2wBpjn
# 303882  @IDzine01 I don't know. It feels like so many ...
#
#                   author_id                created_at  \
# 427640  1492616381715656704 2022-05-12 14:15:28+00:00
# 174922             21538153 2022-05-17 07:08:49+00:00
# 82654   1514353786457710592 2022-05-19 15:40:40+00:00
# 80161            3065078416 2022-05-19 16:11:40+00:00
# 473759           2722561800 2022-05-11 14:15:40+00:00
# ...                     ...                       ...
# 44653   1521322469738655744 2022-05-20 01:55:14+00:00
# 385544           2340448195 2022-05-12 22:29:23+00:00
# 372971  1300485332559855616 2022-05-13 01:09:57+00:00
# 405578  1347917501150224384 2022-05-12 18:45:54+00:00
# 303882             77299448 2022-05-13 22:17:49+00:00
#
#                                            public_metrics  \
# 427640  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 174922  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 82654   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 80161   {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 473759  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...                                                   ...
# 44653   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 385544  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 372971  {'retweet_count': 0, 'reply_count': 2, 'like_c...
# 405578  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 303882  {'retweet_count': 0, 'reply_count': 1, 'like_c...
#
#                                                  entities  \
# 427640  {'mentions': [{'start': 0, 'end': 10, 'usernam...
# 174922  {'urls': [{'start': 137, 'end': 160, 'url': 'h...
# 82654   {'mentions': [{'start': 0, 'end': 9, 'username...
# 80161   {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 473759  {'mentions': [{'start': 0, 'end': 15, 'usernam...
# ...                                                   ...
# 44653   {'annotations': [{'start': 17, 'end': 19, 'pro...
# 385544  {'urls': [{'start': 75, 'end': 98, 'url': 'htt...
# 372971  {'annotations': [{'start': 56, 'end': 58, 'pro...
# 405578  {'mentions': [{'start': 0, 'end': 13, 'usernam...
# 303882  {'mentions': [{'start': 0, 'end': 9, 'username...
#
#                                                    author withheld  \
# 427640  {'created_at': '2022-02-12T21:47:58.000Z', 'na...      NaN
# 174922  {'public_metrics': {'followers_count': 1379, '...      NaN
# 82654   {'public_metrics': {'followers_count': 14, 'fo...      NaN
# 80161   {'verified': False, 'name': 'Dave Swartout', '...      NaN
# 473759  {'username': 'JohnSmith872987', 'id': '2722561...      NaN
# ...                                                   ...      ...
# 44653   {'username': 'RaulFlo09225188', 'name': 'Racer...      NaN
# 385544  {'verified': False, 'name': 'Tom Souther', 'us...      NaN
# 372971  {'public_metrics': {'followers_count': 1426, '...      NaN
# 405578  {'id': '1347917501150224389', 'username': 'She...      NaN
# 303882  {'created_at': '2009-09-25T20:10:46.000Z', 'id...      NaN
#
#                                                clean_text  \
# 427640  dmoehnert oldsalz mailonline there was a dange...
# 174922  karine jeanpierre cant point to a single meeti...
# 82654           elonmusk are you against baby formula too
# 80161   robertkennedyjr rosadelauro to order baby form...
# 473759                                    reallygraceful
# ...                                                   ...
# 44653   senatortimscott tim the dems are onto abortion...
# 385544  the biden administration is shipping pallets o...
# 372971  haxanvillain somehuskervbguy toddstarnes but w...
# 405578                                      jackposobiec
# 303882  idzine01 i dont know it feels like so many mom...
#
#                                           very_clean_text
# 427640  dmoehnert oldsalz mailonline danger issue wbab...
# 174922  karine jeanpierre cant point single meeting br...
# 82654                               elonmusk baby formula
# 80161   robertkennedyjr rosadelauro order baby formula...
# 473759                                     reallygraceful
# ...                                                   ...
# 44653   senatortimscott tim dems onto abortion baby fo...
# 385544  biden administration shipping pallet baby form...
# 372971  haxanvillain somehuskervbguy toddstarnes usa o...
# 405578                                       jackposobiec
# 303882  idzine01 dont know feel like many mom put corn...
#
# [1000 rows x 10 columns]

# %% [markdown]
# ### Sentiment Analyzers

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
import operator
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
def get_sentiment(text):
    '''
    Gets the sentiment score of text from the nltk sentiment thingy.
        Params:
            text (string): Text to analyze
        Returns:
            sent (float): Real number from -1 to 1
    '''
    return sia.polarity_scores(text)["compound"]

from flair.models import TextClassifier
from flair.data import Sentence
flair_sia = TextClassifier.load('en-sentiment')
def get_sentiment_flair(text):
    # RETURNS CONFIDENCE, NOT POLARITY, DO NOT CONFUSE FOR POLARITY CAUSE IT'S CONFIDENCE
    sentence = Sentence(text)
    flair_sia.predict(sentence)
    try:
        pol = sentence.labels[0].to_dict()
    except:
        return 0.0
    if pol["value"] == "NEGATIVE":
        pol["confidence"] *= -1
    return pol["confidence"]
get_sentiment_flair(all_tweets_sample.iloc[0]["very_clean_text"])
all_tweets_sample.iloc[0]["text"]
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/rohan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# 2022-05-29 14:25:34.030255: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-29 14:25:34.030316: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-05-29 14:25:35,702 loading file /home/rohan/.flair/models/sentiment-en-mix-distillbert_4.pt
# '@DMoehnert @OldSalz @MailOnline There was a danger issue w/baby formula poisoning babies...but ZERO proof Abbott Labs was the source...Just more USA Govt EVIL!'

# %%
all_tweets_sample["sentiment"] = all_tweets_sample["clean_text"].apply(get_sentiment)
all_tweets_sample["very_clean_sentiment"] = all_tweets_sample["very_clean_text"].apply(get_sentiment)
all_tweets_sample["flair_sentiment_confidence"] = all_tweets_sample["clean_text"].apply(get_sentiment_flair)
# Out:
# 2022-05-29 14:25:39,873 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:40,723 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:40,784 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:41,810 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:41,872 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:43,123 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:43,293 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:45,520 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:45,642 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:46,070 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:47,150 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:47,642 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:50,673 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:51,071 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:52,667 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:52,956 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:54,726 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-05-29 14:25:54,898 Warning: An empty Sentence was created! Are there empty strings in your dataset?

# %%
def show_sentiments(index):
    display(all_tweets_sample["text"].iloc[index])
    display(all_tweets_sample["sentiment"].iloc[index])
    display(all_tweets_sample["very_clean_sentiment"].iloc[index])
    display(all_tweets_sample["flair_sentiment+confidence"].iloc[index])
show_sentiments(3)
# Out:
# '@RobertKennedyJr @rosadelauro To order baby formula go to Amazon go to the bottom of the page and for location purchase from Canada. Canada doesn’t have a shortage you can have it delivered to your door.'
# 0.3485
# 0.3485
# 0.5740637183189392

# %%
sns.displot(all_tweets_sample["sentiment"], kde=True)

# %%
sns.displot(all_tweets_sample["very_clean_sentiment"], kde=True)

# %%
sns.displot(all_tweets_sample["flair_sentiment_confidence"], kde=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'flair_sentiment_confidence'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <module>
# ----> 1 sns.displot(all_tweets_sample["flair_sentiment_confidence"], kde=True)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'flair_sentiment_confidence'

# %% [markdown]
# ### Roe V Wade Stuff

# %%
roevwade_exp = r"(roe)|(wade)|(abort\w+)|(pro.?life)|(pro.?choice)"
all_tweets_sample["has_abortion_word"] = all_tweets_sample["clean_text"].str.contains(roevwade_exp)
abortion_tweets = all_tweets_sample[all_tweets_sample["has_abortion_word"] == True]
abortion_tweets["text"].apply(lambda x: display(x))
