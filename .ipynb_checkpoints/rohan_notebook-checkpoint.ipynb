# %%
import json
import pandas as pd
import seaborn as sns

# %%
all_tweets = pd.read_json("data/baby_formula.json")

# %%
all_tweets_sample = all_tweets.sample(1000)
all_tweets_sample
# Out:
#                          id  \
# 127445  1527048960002641920
# 529714  1523440861199036416
# 104230  1527215425926221824
# 123228  1527066220586971136
# 34238   1527597472230608896
# ...                     ...
# 310046  1525217955331485696
# 471381  1524406416701902848
# 461228  1524464434147741696
# 267892  1525467482303209472
# 187626  1526313702760259584
#
#                                                      text  \
# 127445  @NBCNews If you have to invoke the Defense Pro...
# 529714  The baby formula supply problem is getting wor...
# 104230  Republicans are Awful human beings.  They care...
# 123228  To the bigots telling birthing parents to "jus...
# 34238   @mikepompeo But not Healthcare, education, vot...
# ...                                                   ...
# 310046  @BetteMidler You do know that if a women doesn...
# 471381  @RepDonBacon You voted yes for a 40 billion bi...
# 461228  Supply chain disruptions and a massive safety ...
# 267892  @NMalliotakis There is a simple solution if yo...
# 187626  Surgeon General to Panicked Parents Looking fo...
#
#                   author_id                created_at  \
# 127445  1510946463819309056 2022-05-18 22:10:17+00:00
# 529714             26331025 2022-05-08 23:13:00+00:00
# 104230             44558414 2022-05-19 09:11:46+00:00
# 123228  1307432151067947008 2022-05-18 23:18:53+00:00
# 34238              60931083 2022-05-20 10:29:53+00:00
# ...                     ...                       ...
# 310046             26294684 2022-05-13 20:54:32+00:00
# 471381  1239765281523798016 2022-05-11 15:09:46+00:00
# 461228             18342955 2022-05-11 19:00:18+00:00
# 267892  1519349987108343808 2022-05-14 13:26:04+00:00
# 187626            340367718 2022-05-16 21:28:38+00:00
#
#                                            public_metrics  \
# 127445  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 529714  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 104230  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 123228  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 34238   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...                                                   ...
# 310046  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 471381  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 461228  {'retweet_count': 1, 'reply_count': 2, 'like_c...
# 267892  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 187626  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                  entities  \
# 127445  {'mentions': [{'start': 0, 'end': 8, 'username...
# 529714  {'urls': [{'start': 50, 'end': 73, 'url': 'htt...
# 104230  {'urls': [{'start': 138, 'end': 161, 'url': 'h...
# 123228                                                NaN
# 34238   {'mentions': [{'start': 0, 'end': 11, 'usernam...
# ...                                                   ...
# 310046  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 471381  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 461228  {'urls': [{'start': 117, 'end': 140, 'url': 'h...
# 267892  {'annotations': [{'start': 79, 'end': 84, 'pro...
# 187626  {'mentions': [{'start': 148, 'end': 162, 'user...
#
#                                                    author withheld
# 127445  {'username': 'TedLasso85', 'id': '151094646381...      NaN
# 529714  {'username': 'tlc6767', 'name': 'Miss T', 'ver...      NaN
# 104230  {'verified': False, 'id': '44558414', 'usernam...      NaN
# 123228  {'created_at': '2020-09-19T21:31:42.000Z', 'us...      NaN
# 34238   {'verified': False, 'public_metrics': {'follow...      NaN
# ...                                                   ...      ...
# 310046  {'public_metrics': {'followers_count': 1006, '...      NaN
# 471381  {'public_metrics': {'followers_count': 308, 'f...      NaN
# 461228  {'created_at': '2008-12-23T21:31:24.000Z', 'id...      NaN
# 267892  {'verified': False, 'public_metrics': {'follow...      NaN
# 187626  {'name': 'going global', 'id': '340367718', 'p...      NaN
#
# [1000 rows x 8 columns]

# %% [markdown]
# ### Cleaning Text

# %%
import re

import nltk.corpus
nltk.download('stopwords')
from nltk.corpus import stopwords

import nltk
nltk.download('omw-1.4')
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

def clean_text_basic(text):
    '''
    Normalizes text, removes unicode chars
        Params:
            text (string): text to be normalized
        Returns:
            cleaned_text (string): The text cleaned with the steps above
    '''
    # regular expression from https://monkeylearn.com/blog/text-cleaning/
    cleaned_text = re.sub(r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", text)
    cleaned_text = cleaned_text.lower()
    return cleaned_text

def clean_text_level2(text):
    '''
    Cleans with the basic steps but also removes stop words and lemmatizes
        Params:
            text (string): text to be normalized
        Returns:
            cleaned_text (string): The text cleaned with the steps above
    '''
    text = clean_text_basic(text)
    stoppies = stopwords.words('english')
    lemmatizer = WordNetLemmatizer()
    # expression partially from https://monkeylearn.com/blog/text-cleaning/
    cleaned_text = " ".join([lemmatizer.lemmatize(word) for word in text.split() if word not in (stoppies)])
    return cleaned_text
# Out:
# [nltk_data] Downloading package stopwords to /home/rohan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/rohan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
all_tweets_sample["clean_text"] = all_tweets_sample["text"].apply(clean_text_basic)
all_tweets_sample["very_clean_text"] = all_tweets_sample["text"].apply(clean_text_level2)
all_tweets_sample
# Out:
#                          id  \
# 127445  1527048960002641920
# 529714  1523440861199036416
# 104230  1527215425926221824
# 123228  1527066220586971136
# 34238   1527597472230608896
# ...                     ...
# 310046  1525217955331485696
# 471381  1524406416701902848
# 461228  1524464434147741696
# 267892  1525467482303209472
# 187626  1526313702760259584
#
#                                                      text  \
# 127445  @NBCNews If you have to invoke the Defense Pro...
# 529714  The baby formula supply problem is getting wor...
# 104230  Republicans are Awful human beings.  They care...
# 123228  To the bigots telling birthing parents to "jus...
# 34238   @mikepompeo But not Healthcare, education, vot...
# ...                                                   ...
# 310046  @BetteMidler You do know that if a women doesn...
# 471381  @RepDonBacon You voted yes for a 40 billion bi...
# 461228  Supply chain disruptions and a massive safety ...
# 267892  @NMalliotakis There is a simple solution if yo...
# 187626  Surgeon General to Panicked Parents Looking fo...
#
#                   author_id                created_at  \
# 127445  1510946463819309056 2022-05-18 22:10:17+00:00
# 529714             26331025 2022-05-08 23:13:00+00:00
# 104230             44558414 2022-05-19 09:11:46+00:00
# 123228  1307432151067947008 2022-05-18 23:18:53+00:00
# 34238              60931083 2022-05-20 10:29:53+00:00
# ...                     ...                       ...
# 310046             26294684 2022-05-13 20:54:32+00:00
# 471381  1239765281523798016 2022-05-11 15:09:46+00:00
# 461228             18342955 2022-05-11 19:00:18+00:00
# 267892  1519349987108343808 2022-05-14 13:26:04+00:00
# 187626            340367718 2022-05-16 21:28:38+00:00
#
#                                            public_metrics  \
# 127445  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 529714  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 104230  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 123228  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 34238   {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...                                                   ...
# 310046  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 471381  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 461228  {'retweet_count': 1, 'reply_count': 2, 'like_c...
# 267892  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 187626  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                  entities  \
# 127445  {'mentions': [{'start': 0, 'end': 8, 'username...
# 529714  {'urls': [{'start': 50, 'end': 73, 'url': 'htt...
# 104230  {'urls': [{'start': 138, 'end': 161, 'url': 'h...
# 123228                                                NaN
# 34238   {'mentions': [{'start': 0, 'end': 11, 'usernam...
# ...                                                   ...
# 310046  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 471381  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 461228  {'urls': [{'start': 117, 'end': 140, 'url': 'h...
# 267892  {'annotations': [{'start': 79, 'end': 84, 'pro...
# 187626  {'mentions': [{'start': 148, 'end': 162, 'user...
#
#                                                    author withheld  \
# 127445  {'username': 'TedLasso85', 'id': '151094646381...      NaN
# 529714  {'username': 'tlc6767', 'name': 'Miss T', 'ver...      NaN
# 104230  {'verified': False, 'id': '44558414', 'usernam...      NaN
# 123228  {'created_at': '2020-09-19T21:31:42.000Z', 'us...      NaN
# 34238   {'verified': False, 'public_metrics': {'follow...      NaN
# ...                                                   ...      ...
# 310046  {'public_metrics': {'followers_count': 1006, '...      NaN
# 471381  {'public_metrics': {'followers_count': 308, 'f...      NaN
# 461228  {'created_at': '2008-12-23T21:31:24.000Z', 'id...      NaN
# 267892  {'verified': False, 'public_metrics': {'follow...      NaN
# 187626  {'name': 'going global', 'id': '340367718', 'p...      NaN
#
#                                                clean_text  \
# 127445  nbcnews if you have to invoke the defense prod...
# 529714   the baby formula supply problem is getting worse
# 104230  republicans are awful human beings  they care ...
# 123228  to the bigots telling birthing parents to just...
# 34238   mikepompeo but not healthcare education voting...
# ...                                                   ...
# 310046  bettemidler you do know that if a women doesnt...
# 471381  repdonbacon you voted yes for a 40 billion bil...
# 461228  supply chain disruptions and a massive safety ...
# 267892  nmalliotakis there is a simple solution if you...
# 187626  surgeon general to panicked parents looking fo...
#
#                                           very_clean_text
# 127445  nbcnews invoke defense production act produce ...
# 529714          baby formula supply problem getting worse
# 104230  republican awful human being care nothing baby...
# 123228  bigot telling birthing parent breastfeed here ...
# 34238   mikepompeo healthcare education voting equal p...
# ...                                                   ...
# 310046  bettemidler know woman doesnt breastfeed begin...
# 471381  repdonbacon voted yes 40 billion bill didnt ev...
# 461228  supply chain disruption massive safety recall ...
# 267892  nmalliotakis simple solution cant get baby for...
# 187626  surgeon general panicked parent looking baby f...
#
# [1000 rows x 10 columns]

# %%
from wordcloud import WordCloud

all_tweet_words = ' '.join(list(all_tweets_sample["very_clean_text"]))
all_tweets_wordcloud = WordCloud().generate(all_tweet_words)
all_tweets_wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FC4A68DB790>

# %% [markdown]
# ### Sentiment Analyzers

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
import operator
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
def get_sentiment(text):
    '''
    Gets the sentiment score of text from the nltk sentiment thingy.
        Params:
            text (string): Text to analyze
        Returns:
            sent (float): Real number from -1 to 1
    '''
    return sia.polarity_scores(text)["compound"]

from flair.models import TextClassifier
from flair.data import Sentence
flair_sia = TextClassifier.load('en-sentiment')
def get_sentiment_flair(text):
    # RETURNS CONFIDENCE, NOT POLARITY, DO NOT CONFUSE FOR POLARITY CAUSE IT'S CONFIDENCE
    sentence = Sentence(text)
    flair_sia.predict(sentence)
    try:
        pol = sentence.labels[0].to_dict()
    except:
        return 0.0
    if pol["value"] == "NEGATIVE":
        pol["confidence"] *= -1
    return pol["confidence"]
get_sentiment_flair(all_tweets_sample.iloc[0]["very_clean_text"])
all_tweets_sample.iloc[0]["text"]
# Out:
# 2022-06-05 14:14:17,687 loading file /home/rohan/.flair/models/sentiment-en-mix-distillbert_4.pt
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/rohan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# "@NBCNews If you have to invoke the Defense Production Act to produce baby formula, maybe you're just terrible at your job?"

# %%
all_tweets_sample["sentiment"] = all_tweets_sample["clean_text"].apply(get_sentiment)
all_tweets_sample["very_clean_sentiment"] = all_tweets_sample["very_clean_text"].apply(get_sentiment)
all_tweets_sample["flair_sentiment_confidence"] = all_tweets_sample["clean_text"].apply(get_sentiment_flair)
# Out:
# 2022-06-05 14:14:21,574 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:21,771 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:21,772 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:24,681 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:24,985 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:25,084 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:25,230 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:27,197 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:27,569 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:28,390 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:29,060 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:29,810 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:30,172 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:36,203 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:39,136 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:39,885 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2022-06-05 14:14:40,158 Warning: An empty Sentence was created! Are there empty strings in your dataset?

# %%
def show_sentiments(index):
    display(all_tweets_sample["text"].iloc[index])
    display(all_tweets_sample["sentiment"].iloc[index])
    display(all_tweets_sample["very_clean_sentiment"].iloc[index])
    display(all_tweets_sample["flair_sentiment_confidence"].iloc[index])
show_sentiments(3)
# Out:
# 'To the bigots telling birthing parents to "just breastfeed", here\'s some fact checks for you.\n\nThere are multiple health issues that prevent or greatly decrease the possibility for a person to breastfeed. Some babies have allergies or reactions to galactose, which is a sugar'
# 0.0258
# 0.0258
# -0.9418197870254517

# %%
sns.displot(all_tweets_sample["sentiment"], kde=True)

# %%
sns.displot(all_tweets_sample["very_clean_sentiment"], kde=True)

# %%
sns.displot(all_tweets_sample["flair_sentiment_confidence"], kde=True)

# %% [markdown]
# ### Roe V Wade Stuff

# %%
roevwade_exp = r"(roe)|(wade)|(abort\w+)|(pro.?life)|(pro.?choice)|(fetus)"
all_tweets_sample["has_abortion_word"] = all_tweets_sample["clean_text"].str.contains(roevwade_exp)
abortion_tweets = all_tweets_sample[all_tweets_sample["has_abortion_word"] == True]
display(len(abortion_tweets))
abortion_tweets["text"].apply(lambda x: display(x))
# Out:
# /tmp/ipykernel_19258/782945545.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#
# '@RepMTG Well since you had an abortion you won’t need any baby formula. amirite?'
# "Love you @2RawTooReal 'Riddle me this: Why would 192 pro life Republicans vote against funding  for #BabyFormulaShortage?'\nThey don't care about life outside the womb..They are not pro life....They are \n#ProPoverty https://t.co/J11p256g9E"
# 'you say “adoption&gt;abortion” and then say “just breastfeed” your heads are empty and desolate. you people are brainless, mindless, and foolish. you doltish hogs drive me insane.'
# "@BigDikNRG1 @jsessions8032 @Higgles111 @PartyHeroez @DonaldJTrumpJr So, you're saying Laurene Powell Jobs is the villain behind the baby formula crisis?  Are you sure?  Doesn't sound accurate to me."
# 434743    None
# 46566     None
# 400350    None
# 270998    None
# 291214    None
# 404393    None
# 448328    None
# 481192    None
# 443162    None
# 96444     None
# 82110     None
# 106292    None
# 77957     None
# 40520     None
# 174780    None
# 46269     None
# 43853     None
# 81861     None
# 515359    None
# 473856    None
# 364961    None
# 206444    None
# 30543     None
# 518695    None
# 353269    None
# 494811    None
# 295343    None
# 279742    None
# 162214    None
# 19285     None
# 46545     None
# 86212     None
# 346329    None
# 486770    None
# 50954     None
# 6149      None
# 212197    None
# Name: text, dtype: object

# %%
from wordcloud import WordCloud
all_abortion_words = ' '.join(list(abortion_tweets["very_clean_text"]))
abortion_wordcloud = WordCloud().generate(all_abortion_words)
abortion_wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FC4A4916B80>

# %% [markdown]
# ### Operation Fly

# %%
# op_fly = pd.read_json("data/biden_responses.json")
op_fly_saved = pd.read_csv("data/biden_replies_cleaned.csv")
op_fly_saved
# Out:
#        Unnamed: 0                                           entities  \
# 0               0  {'urls': [{'start': 86, 'end': 109, 'url': 'ht...
# 1               1  {'urls': [{'start': 86, 'end': 109, 'url': 'ht...
# 2               2  {'mentions': [{'start': 0, 'end': 13, 'usernam...
# 3               3  {'mentions': [{'start': 0, 'end': 6, 'username...
# 4               4  {'mentions': [{'start': 0, 'end': 6, 'username...
# ...           ...                                                ...
# 23565       23565  {'mentions': [{'start': 0, 'end': 6, 'username...
# 23566       23566  {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 23567       23567  {'mentions': [{'start': 0, 'end': 11, 'usernam...
# 23568       23568  {'mentions': [{'start': 0, 'end': 15, 'usernam...
# 23569       23569  {'mentions': [{'start': 0, 'end': 14, 'usernam...
#
#                  author_id                                  referenced_tweets  \
# 0                487068024  [{'type': 'replied_to', 'id': '153110333409395...
# 1                487068024  [{'type': 'replied_to', 'id': '153110570657266...
# 2               2385907231  [{'type': 'replied_to', 'id': '153110333409395...
# 3      1518790002087366656  [{'type': 'replied_to', 'id': '152837963322949...
# 4      1525528634538196992  [{'type': 'replied_to', 'id': '152837963322949...
# ...                    ...                                                ...
# 23565  1490402219317153792  [{'type': 'replied_to', 'id': '152837963322949...
# 23566  1483662538315218944  [{'type': 'replied_to', 'id': '152840991425889...
# 23567  1483662538315218944  [{'type': 'replied_to', 'id': '152842268813346...
# 23568  1165009295651561472  [{'type': 'replied_to', 'id': '152838252959356...
# 23569  1483662538315218944  [{'type': 'replied_to', 'id': '152845938149018...
#
#                                                     text  \
# 0      @bruceharder8 @clvmatt @colgraphics @PalimenoF...
# 1      @bruceharder8 @PalimenoForGAD1 @clvmatt @colgr...
# 2      @bruceharder8 @Neoplasmosis @colgraphics @Pali...
# 3             @POTUS Too little too late Jojo as always.
# 4                     @POTUS Paid for by the tax payers.
# ...                                                  ...
# 23565  @POTUS Eventually our Mr. President thinks up ...
# 23566  @PalimenoForGAD1 @POTUS No this started in Sep...
# 23567  @LadyRaven3 @POTUS Really the started in Septe...
# 23568  @RightofOpinion @POTUS 😂😂😂😂😂😂😂 PATÉTICO nivel ...
# 23569  @Sere_nycagent @POTUS Really Biden. It’s too b...
#
#                                           public_metrics                   id  \
# 0      {'retweet_count': 0, 'reply_count': 0, 'like_c...  1531223799701577728
# 1      {'retweet_count': 0, 'reply_count': 0, 'like_c...  1531223625390559232
# 2      {'retweet_count': 0, 'reply_count': 0, 'like_c...  1531214744362921984
# 3      {'retweet_count': 0, 'reply_count': 0, 'like_c...  1531140543849242624
# 4      {'retweet_count': 0, 'reply_count': 0, 'like_c...  1531127324569051136
# ...                                                  ...                  ...
# 23565  {'retweet_count': 0, 'reply_count': 0, 'like_c...  1529263752230514688
# 23566  {'retweet_count': 0, 'reply_count': 0, 'like_c...  1529263654125785088
# 23567  {'retweet_count': 0, 'reply_count': 1, 'like_c...  1529263311237173248
# 23568  {'retweet_count': 0, 'reply_count': 0, 'like_c...  1529263116378415104
# 23569  {'retweet_count': 0, 'reply_count': 0, 'like_c...  1529262817324376064
#
#                       created_at  \
# 0      2022-05-30 10:39:37+00:00
# 1      2022-05-30 10:38:55+00:00
# 2      2022-05-30 10:03:38+00:00
# 3      2022-05-30 05:08:47+00:00
# 4      2022-05-30 04:16:15+00:00
# ...                          ...
# 23565  2022-05-25 00:51:05+00:00
# 23566  2022-05-25 00:50:42+00:00
# 23567  2022-05-25 00:49:20+00:00
# 23568  2022-05-25 00:48:33+00:00
# 23569  2022-05-25 00:47:22+00:00
#
#                                                   author  geo  \
# 0      {'name': 'BDouble', 'username': 'Neoplasmosis'...  NaN
# 1      {'name': 'BDouble', 'username': 'Neoplasmosis'...  NaN
# 2      {'name': 'Matthew', 'username': 'clvmatt', 'id...  NaN
# 3      {'name': 'Deborah', 'username': 'Eckkonis51', ...  NaN
# 4      {'name': 'Randle Mcmurph', 'username': 'Mcmurp...  NaN
# ...                                                  ...  ...
# 23565  {'username': 'Christi89764237', 'created_at': ...  NaN
# 23566  {'username': 'bdelos57', 'created_at': '2022-0...  NaN
# 23567  {'username': 'bdelos57', 'created_at': '2022-0...  NaN
# 23568  {'username': 'CharlieWings07', 'created_at': '...  NaN
# 23569  {'username': 'bdelos57', 'created_at': '2022-0...  NaN
#
#                                               clean_text  \
# 0      bruceharder8 clvmatt colgraphics palimenoforga...
# 1      bruceharder8 palimenoforgad1 clvmatt colgraphi...
# 2      bruceharder8 neoplasmosis colgraphics palimeno...
# 3               potus too little too late jojo as always
# 4                       potus paid for by the tax payers
# ...                                                  ...
# 23565  potus eventually our mr president thinks up hi...
# 23566  palimenoforgad1 potus no this started in septe...
# 23567  ladyraven3 potus really the started in septemb...
# 23568           rightofopinion potus  pattico nivel dios
# 23569  serenycagent potus really biden its too bad he...
#
#                                          very_clean_text  sentiment  \
# 0      bruceharder8 clvmatt colgraphics palimenoforga...     0.0000
# 1      bruceharder8 palimenoforgad1 clvmatt colgraphi...     0.0000
# 2      bruceharder8 neoplasmosis colgraphics palimeno...     0.1280
# 3                          potus little late jojo always     0.0000
# 4                                   potus paid tax payer     0.0000
# ...                                                  ...        ...
# 23565  potus eventually mr president think constituen...     0.8360
# 23566  palimenoforgad1 potus started september 2021 w...    -0.8126
# 23567  ladyraven3 potus really started september octo...    -0.6705
# 23568            rightofopinion potus pattico nivel dios     0.0000
# 23569  serenycagent potus really biden bad ensure som...    -0.5242
#
#        very_clean_sentiment  flair_sentiment_confidence
# 0                    0.0000                    0.977852
# 1                    0.0000                    0.952617
# 2                    0.1280                    0.999565
# 3                    0.0000                   -0.983392
# 4                    0.0000                   -0.983837
# ...                     ...                         ...
# 23565                0.8360                   -0.999140
# 23566                0.6658                   -0.999986
# 23567               -0.6705                   -0.999932
# 23568                0.0000                   -0.999827
# 23569                0.0990                   -0.999614
#
# [23570 rows x 15 columns]

# %%
# op_fly["clean_text"] = op_fly["text"].apply(clean_text_basic)
# op_fly["very_clean_text"] = op_fly["text"].apply(clean_text_level2)
# op_fly

# %%
# op_fly["sentiment"] = op_fly["clean_text"].apply(get_sentiment)
# op_fly["very_clean_sentiment"] = op_fly["very_clean_text"].apply(get_sentiment)
# op_fly["flair_sentiment_confidence"] = op_fly["clean_text"].apply(get_sentiment_flair)

# %%
sns.displot(op_fly_saved["sentiment"], kde=True)

# %%
sns.displot(op_fly_saved["very_clean_sentiment"], kde=True)

# %%
sns.displot(op_fly_saved["flair_sentiment_confidence"], kde=True)

# %%
op_fly_words = ' '.join(list(op_fly_saved["very_clean_text"]))
op_fly_wordcloud = WordCloud().generate(op_fly_words)
op_fly_wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FC4A68C70D0>

# %%
# op_fly.to_csv("biden_replies_cleaned.csv")

# %% [markdown]
# ### Scammers

# %%
all_tweets_sample["potential_scam"] = all_tweets_sample["clean_text"].str.match(r"(venmo)|(zelle)|(gift card)|(cash)|(paypal)")

# %%
all_tweets_sample["bbabybb"] = all_tweets_sample["clean_text"].str.match("baby")

# %%
all_tweets_sample["bbabybb"
# Out:
# 127445    False
# 529714    False
# 104230    False
# 123228    False
# 34238     False
#           ...
# 310046    False
# 471381    False
# 461228    False
# 267892    False
# 187626    False
# Name: bbabybb, Length: 1000, dtype: bool
